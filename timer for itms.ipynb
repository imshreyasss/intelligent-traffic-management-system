# %%
import time

my_time = int(input("enter the time : "))

for x in range (my_time , 0, -1):
    print(x)
    time.sleep(1)

print("TIME'S UP SHREY!")
# Out:
# enter the time : 3
# 3
# 2
# 1
# TIME'S UP SHREY!
